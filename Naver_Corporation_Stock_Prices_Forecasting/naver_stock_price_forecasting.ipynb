2016-06-22,139800,146000,139800,146000,144651.25,1005435\r\n2016-06-23,146600,152000,146400,149400,148019.8281,1130610\r\n2016-06-24,149000,151800,144200,147800,146434.625,867905\r\n2016-06-27,145600,146000,141200,142000,140688.2031,1174480\r\n2016-06-28,140200,143800,140000,143800,142471.5781,770085\r\n2016-06-29,143000,144800,142600,142600,141282.6406,741970\r\n2016-06-30,142000,143400,141400,142000,140688.2031,767665\r\n2016-07-01,142600,144600,142600,142600,141282.6406,382845\r\n2016-07-04,143200,145800,142400,145400,144056.7813,589185\r\n2016-07-05,146000,151200,146000,150000,148614.2813,635330\r\n2016-07-06,150000,150000,146000,149000,147623.5469,612230\r\n2016-07-07,150400,154000,149600,150600,149208.75,342580\r\n2016-07-08,150200,151200,149600,150000,148614.2813,368765\r\n2016-07-11,149000,151600,148600,150800,149406.8906,541025\r\n2016-07-12,151800,153600,149600,151000,149605.0469,635055\r\n2016-07-13,152000,153600,149600,151600,150199.5,775750\r\n2016-07-14,150200,150800,146800,146800,145443.8438,827050\r\n2016-07-15,150000,150600,141200,143200,141877.125,1530420\r\n2016-07-18,143400,143600,141200,142400,141084.5156,754640\r\n2016-07-19,143600,144200,141400,143600,142273.4375,553990\r\n2016-07-20,143000,143400,138200,139000,137715 ...

# %%
data = pd.read_csv('naver.csv')
data.head()
# Out:
#          Date      Open      High       Low     Close    Adj Close    Volume
# 0  2016-04-18  133600.0  134400.0  131400.0  132200.0  130978.7344  374705.0
# 1  2016-04-19  132200.0  134400.0  132200.0  133800.0  132563.9375  451405.0
# 2  2016-04-20  133200.0  133600.0  130200.0  130800.0  129591.6641  463915.0
# 3  2016-04-21  132000.0  133400.0  131200.0  133400.0  132167.6563  412070.0
# 4  2016-04-22  132000.0  133000.0  131400.0  132600.0  131375.0313  194870.0

# %% [markdown]
# - Open(시가): 주식에서 처음 거래된 가격(우리나라 오전 9시)
# - Close(종가): 당일 맨 마지막 거래가 체결된 가격(우리나라 오후 3시)
# - High/Low: 최고거래가/최저거래가
# - Adj Close: 수정 종가라는 뜻으로 분할, 배당, 배분, 신주 발생이 된 경우를 고려해 주식 가격을 조정(adjustment)해둔 가격
# - Volume: 주식거래량

# %% [markdown]
# # **Data preprocessing**

# %%
# 데이터 개수 파악
data.count()
# Out:
# Date         1227
# Open         1222
# High         1222
# Low          1222
# Close        1222
# Adj Close    1222
# Volume       1222
# dtype: int64

# %%
# 결측치 개수 파악
data.isnull().sum()
# Out:
# Date         0
# Open         5
# High         5
# Low          5
# Close        5
# Adj Close    5
# Volume       5
# dtype: int64

# %%
# 결측치가 있는 행 제거
data = data.dropna()
data.count()
# Out:
# Date         1222
# Open         1222
# High         1222
# Low          1222
# Close        1222
# Adj Close    1222
# Volume       1222
# dtype: int64

# %%
# 고가와 저가의 중간 가격 구하기
high_prices = data['High'].values
low_prices = data['Low'].values
mid_prices = (high_prices + low_prices) / 2

# %% [markdown]
# # **Visualize time series data**

# %%
# 그래프로 시각화 해보기
sns.set_style('whitegrid')
plt.figure(figsize=(15, 5))
plt.plot(mid_prices, c = 'g')
plt.title("Naver Corporation Stock Prices for 5 years", size = 15, y = 1.02)
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# # **Create Windows**
# - Window Size = 50 + 1
# - 첫 번째 window는 50일 치의 값으로 그 다음 날의 값을 예측한다.
# - 그리고 두 번째 window는 하루 씩 밀려서 첫 날의 그 다음 날부터 50일치의 값으로 그 다음 날의 값을 예측한다.
# - 이러한 과정을 반복한다.

# %%
n_steps = 50 # time step = 50 
sequence_length = n_steps + 1 # 총 window size

# 리스트 생성
series = [] 

# result 리스트는 index 별로 51일치의 data가 들어감. 총 길이는 전체에서 51일을 뺀 값
for index in range(len(mid_prices) - sequence_length):
    series.append(mid_prices[index:index + sequence_length])

# %%
len(series[0])
# Out:
# 51

# %%
len(series)
# Out:
# 1171

# %% [markdown]
# # **Normalize Data**

# %%
normalized_data = []
window_mean = []
window_std = []

# Z-Score Normalization
for window in series:
    normalized_window = [((p - np.mean(window))/np.std(window)) for p in window]
    normalized_data.append(normalized_window) 
    window_mean.append(np.mean(window))
    window_std.append(np.std(window))

# 여기서 result는 Z-Score Normalization 되어진 dataset
series = np.array(normalized_data)

# %% [markdown]
# # **Train Valid Test split**

# %%
# 전체를 7:2:1 으로 분할
row1 = int(round(series.shape[0] * 0.7))
row2 = int(round(series.shape[0] * 0.2))
print(row1, row2, len(series) - (row1+row2))
# Out:
# 820 234 117

# %%
# train, valid, test 분할
X_train, y_train = series[:row1, :n_steps], series[:row1, -1]
X_valid, y_valid = series[row1:row1+row2, :n_steps], series[row1:row1+row2, -1]
X_test, y_test = series[row1+row2:, :n_steps], series[row1+row2:, -1]

# %%
X_train.shape, y_train.shape
# Out:
# ((820, 50), (820,))

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_valid = X_valid.reshape(X_valid.shape[0], X_valid.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

y_train = y_train.reshape(y_train.shape[0], 1)
y_valid = y_valid.reshape(y_valid.shape[0], 1)
y_test = y_test.reshape(y_test.shape[0], 1)

X_train.shape, y_train.shape
# Out:
# ((820, 50, 1), (820, 1))

# %% [markdown]
# - 학습데이터: 배치 사이즈 = 820, 타입 스텝 수 = 50, 단변량 값

# %% [markdown]
# # **Build a Model**

# %%
model = Sequential()

model.add(LSTM(50, return_sequences=True, input_shape=(50, 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(1, activation='linear'))
model.compile(loss='mse', optimizer='adam')

model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_25 (LSTM)               (None, 50, 50)            10400
# _________________________________________________________________
# lstm_26 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **Training**

# %%
model.fit(X_train, y_train, 
          epochs=15,
          validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/15
# 26/26 [==============================] - 5s 77ms/step - loss: 1.4075 - val_loss: 0.6647
# Epoch 2/15
# 26/26 [==============================] - 1s 48ms/step - loss: 0.5701 - val_loss: 0.5048
# Epoch 3/15
# 26/26 [==============================] - 1s 48ms/step - loss: 0.4722 - val_loss: 0.4062
# Epoch 4/15
# 26/26 [==============================] - 1s 48ms/step - loss: 0.3738 - val_loss: 0.3166
# Epoch 5/15
# 26/26 [==============================] - 1s 52ms/step - loss: 0.2930 - val_loss: 0.2709
# Epoch 6/15
# 26/26 [==============================] - 1s 47ms/step - loss: 0.2162 - val_loss: 0.2572
# Epoch 7/15
# 26/26 [==============================] - 1s 48ms/step - loss: 0.1949 - val_loss: 0.2060
# Epoch 8/15
# 26/26 [==============================] - 1s 46ms/step - loss: 0.1590 - val_loss: 0.2076
# Epoch 9/15
# 26/26 [==============================] - 1s 46ms/step - loss: 0.1555 - val_loss: 0.1960
# Epoch 10/15
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1493 - val_loss: 0.1925
# Epoch 11/15
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1398 - val_loss: 0.1926
# Epoch 12/15
# 26/26 [==============================] - 1s 46ms/step - loss: 0.1398 - val_loss: 0.2182
# Epoch 13/15
# 26/26 [==============================] - 1s 48ms/step - loss: 0.1564 - val_loss: 0.1939
# Epoch 14/15
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1530 - val_loss: 0.2079
# Epoch 15/15
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1526 - val_loss: 0.1940

# %% [markdown]
# # **Prediction**

# %%
# 테스트 데이터 평가
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2633
# 0.26333382725715637

# %%
# 예측값 구하기
predicted = model.predict(X_test)

# %%
# 시각화
sns.set_style('whitegrid')
fig = plt.figure(figsize=(15, 5))
plt.plot(y_test, label='True', c = 'g')
plt.plot(predicted, label='Prediction', c = 'r')
plt.title("Naver Corporation Stock Prices Prediction", size = 15, y = 1.02)
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend(fontsize = 15)
plt.show()
