# %% [markdown]
# <a href="https://colab.research.google.com/github/jhlee508/Colab/blob/master/SCSE_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ruthetum/SCSE.git
# Out:
# Cloning into 'SCSE'...
# remote: Enumerating objects: 273, done.
# remote: Counting objects: 100% (273/273), done.
# remote: Compressing objects: 100% (219/219), done.
# remote: Total 273 (delta 100), reused 206 (delta 43), pack-reused 0
# Receiving objects: 100% (273/273), 39.83 MiB | 19.99 MiB/s, done.
# Resolving deltas: 100% (100/100), done.

# %%
import os
os.chdir('/content/SCSE')

# %%
# !git pull origin tracking
# Out:
# From https://github.com/ruthetum/SCSE
#  * branch            tracking   -> FETCH_HEAD
# Updating 0c45176..f589f03
# Fast-forward
#  .gitignore                                         |    9 +-
#  .../__pycache__/evaluate_depth.cpython-37.pyc      |  Bin 0 -> 6018 bytes
#  .../__pycache__/kitti_utils.cpython-37.pyc         |  Bin 0 -> 3035 bytes
#  DepthEstimation/__pycache__/layers.cpython-37.pyc  |  Bin 0 -> 8385 bytes
#  DepthEstimation/__pycache__/options.cpython-37.pyc |  Bin 0 -> 4932 bytes
#  DepthEstimation/__pycache__/utils.cpython-37.pyc   |  Bin 0 -> 3862 bytes
#  DepthEstimation/datasets/__init__.py               |    1 +
#  .../datasets/__pycache__/__init__.cpython-37.pyc   |  Bin 0 -> 261 bytes
#  .../__pycache__/kitti_dataset.cpython-37.pyc       |  Bin 0 -> 4650 bytes
#  .../__pycache__/mono_dataset.cpython-37.pyc        |  Bin 0 -> 5846 bytes
#  DepthEstimation/datasets/kitti_dataset.py          |  134 +++
# ...

# %%
os.chdir('SpeedEstimation')

# %%
# !python main.py --weights '/content/yolov5s.pt' --classes 2 --conf 0.7 --source '/content/video11.mp4' --model_name mono+stereo_640x192
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=[2], conf_thres=0.7, device='', exist_ok=False, fps=30, half=False, hide_conf=False, hide_labels=False, imgsz=640, iou_thres=0.45, line_thickness=3, max_det=1000, model_name='mono+stereo_640x192', name='exp', no_cuda=False, nosave=False, pred_metric_depth=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='/content/video11.mp4', update=False, view_img=False, weights=['/content/yolov5s.pt'])
# requirements: /content/SCSE/SpeedEstimation/requirements.txt not found, check failed.
# YOLOv5 🚀 f589f03 torch 1.9.0+cu102 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# -> Loading model from  models/mono+stereo_640x192
#    Loading pretrained encoder
#    Loading pretrained decoder
# Loading weights from deep_sort_pytorch/deep_sort/deep/checkpoint/ckpt.t7... Done!
# Fusing layers...
# Model Summary: 224 layers, 7266973 parameters, 0 gradients
# ...

# %%
# !python main.py --weights '/content/yolov5s.pt' --classes 2 --conf 0.7 --source '/content/video12.mp4' --model_name mono+stereo_1024x320
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=[2], conf_thres=0.7, device='', exist_ok=False, fps=30, half=False, hide_conf=False, hide_labels=False, imgsz=640, iou_thres=0.45, line_thickness=3, max_det=1000, model_name='mono+stereo_1024x320', name='exp', no_cuda=False, nosave=False, pred_metric_depth=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='/content/video12.mp4', update=False, view_img=False, weights=['/content/yolov5s.pt'])
# requirements: /content/SCSE/SpeedEstimation/requirements.txt not found, check failed.
# YOLOv5 🚀 f589f03 torch 1.9.0+cu102 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# -> Loading model from  models/mono+stereo_1024x320
#    Loading pretrained encoder
#    Loading pretrained decoder
# Loading weights from deep_sort_pytorch/deep_sort/deep/checkpoint/ckpt.t7... Done!
# Fusing layers...
# Model Summary: 224 layers, 7266973 parameters, 0 gradients
# ...
